# %%
import pandas as pd

# %%
wedding_merged = pd.read_csv(r'C:\Users\NB\OneDrive\Dokumenty\aDA_24_PROJECT\wedding_merged.csv')
cheese_merged = pd.read_csv(r'C:\Users\NB\OneDrive\Dokumenty\aDA_24_PROJECT\cheese_merged.csv')
cheeses = pd.read_csv(r'C:\Users\NB\OneDrive\Dokumenty\aDA_24_PROJECT\cheeses.csv')
wedding = pd.read_csv(r'C:\Users\NB\OneDrive\Dokumenty\aDA_24_PROJECT\wedding.csv')

# %%
# Filtrování řádků, kde je ve sloupci "cheese" hodnota "Petit-Suisse"
filtered_result = cheese_merged[cheese_merged['cheese'] == 'Petit-Suisse'][['cheese', 'type_hard']]

# Zobrazení výsledku
print(filtered_result)
# Out:
#            cheese  type_hard
# 927  Petit-Suisse      False

# %%
wedding_merged.head(1)
# Out:
#   Type of Wine          Wine Grape Estilo Vinho Característica Vinho 1  \
# 0          red  Cabernet Sauvignon    Encorpado         Taninos firmes
#
#   Característica Vinho 2 Característica Vinho 3 Característica Vinho 4  \
# 0          frutas negras            especiarias                    NaN
#
#   Tipo de Queijo Família Queijo        Textura Queijo  ...  \
# 0           Azul           Azul  Cremosa, esfarelante  ...
#
#   flavor_pronounced_aroma flavor_salty flavor_slightly_acidic  \
# 0                   False         True                  False
#
#   flavor_slightly_fruity flavor_slightly_salty flavor_slightly_spicy  \
# 0                  False                 False                 False
#
#   flavor_slightly_sweet flavor_spicy  flavor_velvety                wedding_ID
# 0                 False         True           False  red - Cabernet Sauvignon
#
# [1 rows x 68 columns]

# %%
selected_columns = cheeses[['cheese', 'url', 'milk', 'type', 'texture', 'flavor', 'vegetarian', 'vegan']]
selected_columns.head()
# Out:
#               cheese                                        url   milk  \
# 0         Aarewasser         https://www.cheese.com/aarewasser/    cow
# 1   Abbaye de Belloc   https://www.cheese.com/abbaye-de-belloc/  sheep
# 2   Abbaye de Belval   https://www.cheese.com/abbaye-de-belval/    cow
# 3  Abbaye de Citeaux  https://www.cheese.com/abbaye-de-citeaux/    cow
# 4    Abbaye de Tamié              https://www.cheese.com/tamie/    cow
#
#                          type                texture                 flavor  \
# 0                   semi-soft                buttery                  sweet
# 1          semi-hard, artisan    creamy, dense, firm          burnt caramel
# 2                   semi-hard                elastic                    NaN
# 3  semi-soft, artisan, brined  creamy, dense, smooth  acidic, milky, smooth
# 4               soft, artisan   creamy, open, smooth          fruity, nutty
#
#   vegetarian  vegan
# 0      False  False
# 1       True  False
# ...

# %%
selected_columns = wedding[['Tipo Vinho', 'Uva Vinho', 'Característica Vinho 1', 'Característica Vinho 2', 'Característica Vinho 3', 'Característica Vinho 4', 'Tipo de Queijo', 'Textura Queijo', 'Sabor Queijo 1', 'Sabor Queijo 2', 'Sabor Queijo 3', 'Sabor Queijo 4']]
selected_columns.head()
# Out:
#   Tipo Vinho           Uva Vinho Característica Vinho 1  \
# 0      Tinto  Cabernet Sauvignon         Taninos firmes
# 1      Tinto  Cabernet Sauvignon         Taninos firmes
# 2      Tinto  Cabernet Sauvignon         Taninos firmes
# 3      Tinto  Cabernet Sauvignon         Taninos firmes
# 4      Tinto  Cabernet Sauvignon         Taninos firmes
#
#   Característica Vinho 2 Característica Vinho 3 Característica Vinho 4  \
# 0          frutas negras            especiarias                    NaN
# 1          frutas negras            especiarias                    NaN
# 2          frutas negras            especiarias                    NaN
# 3          frutas negras            especiarias                    NaN
# 4          frutas negras            especiarias                    NaN
#
#   Tipo de Queijo        Textura Queijo Sabor Queijo 1      Sabor Queijo 2  \
# 0           Azul  Cremosa, esfarelante        Intenso             salgado
# ...

# %%
cheese_merged.head()
# Out:
#               cheese                                        url   milk  \
# 0         Aarewasser         https://www.cheese.com/aarewasser/    cow
# 1   Abbaye de Belloc   https://www.cheese.com/abbaye-de-belloc/  sheep
# 2   Abbaye de Belval   https://www.cheese.com/abbaye-de-belval/    cow
# 3  Abbaye de Citeaux  https://www.cheese.com/abbaye-de-citeaux/    cow
# 4    Abbaye de Tamié              https://www.cheese.com/tamie/    cow
#
#        country       region family                        type fat_content  \
# 0  Switzerland          NaN    NaN                   semi-soft         NaN
# 1       France  Pays Basque    NaN          semi-hard, artisan         NaN
# 2       France          NaN    NaN                   semi-hard      40-46%
# 3       France     Burgundy    NaN  semi-soft, artisan, brined         NaN
# 4       France       Savoie    NaN               soft, artisan         NaN
#
#   calcium_content                texture  ... flavor_nutty  \
# ...
